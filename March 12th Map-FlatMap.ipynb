# %%
# File location and type
file_location = "/FileStore/tables/bestsellers_with_categories.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: [Row(Name=&#39;10-Day Green Smoothie Cleanse&#39;, Author=&#39;JJ Smith&#39;, User Rating=4.7, Reviews=17350, Price=8, Year=2016, Genre=&#39;Non Fiction&#39;),
#  Row(Name=&#39;11/22/63: A Novel&#39;, Author=&#39;Stephen King&#39;, User Rating=4.6, Reviews=2052, Price=22, Year=2011, Genre=&#39;Fiction&#39;),
#  Row(Name=&#39;12 Rules for Life: An Antidote to Chaos&#39;, Author=&#39;Jordan B. Peterson&#39;, User Rating=4.7, Reviews=18979, Price=15, Year=2018, Genre=&#39;Non Fiction&#39;),
# ...

# %%
type(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: pyspark.sql.dataframe.DataFrame</div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 550</div>

# %%
df.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: Row(Name=&#39;10-Day Green Smoothie Cleanse&#39;, Author=&#39;JJ Smith&#39;, User Rating=4.7, Reviews=17350, Price=8, Year=2016, Genre=&#39;Non Fiction&#39;)</div>

# %%
df.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [Row(Name=&#39;10-Day Green Smoothie Cleanse&#39;, Author=&#39;JJ Smith&#39;, User Rating=4.7, Reviews=17350, Price=8, Year=2016, Genre=&#39;Non Fiction&#39;),
#  Row(Name=&#39;11/22/63: A Novel&#39;, Author=&#39;Stephen King&#39;, User Rating=4.6, Reviews=2052, Price=22, Year=2011, Genre=&#39;Fiction&#39;)]</div>

# %%
text_file=sc.textFile('/FileStore/tables/bestsellers_with_categories.csv')
text_file.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: [&#39;Name,Author,User Rating,Reviews,Price,Year,Genre&#39;,
#  &#39;10-Day Green Smoothie Cleanse,JJ Smith,4.7,17350,8,2016,Non Fiction&#39;]</div>

# %%
a = text_file.flatMap(lambda x:x.split(' '))
a.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [&#39;Name,Author,User&#39;,
#  &#39;Rating,Reviews,Price,Year,Genre&#39;,
#  &#39;10-Day&#39;,
#  &#39;Green&#39;,
#  &#39;Smoothie&#39;]</div>

# %%
a = text_file.map(lambda x:x.split(' '))
a.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: [[&#39;Name,Author,User&#39;, &#39;Rating,Reviews,Price,Year,Genre&#39;],
#  [&#39;10-Day&#39;,
#   &#39;Green&#39;,
#   &#39;Smoothie&#39;,
#   &#39;Cleanse,JJ&#39;,
#   &#39;Smith,4.7,17350,8,2016,Non&#39;,
#   &#39;Fiction&#39;],
#  [&#39;11/22/63:&#39;, &#39;A&#39;, &#39;Novel,Stephen&#39;, &#39;King,4.6,2052,22,2011,Fiction&#39;],
#  [&#39;12&#39;,
#   &#39;Rules&#39;,
#   &#39;for&#39;,
#   &#39;Life:&#39;,
#   &#39;An&#39;,
#   &#39;Antidote&#39;,
#   &#39;to&#39;,
#   &#39;Chaos,Jordan&#39;,
#   &#39;B.&#39;,
#   &#39;Peterson,4.7,18979,15,2018,Non&#39;,
#   &#39;Fiction&#39;],
# ...

# %%
RDD vs DF
DF vs DataSet
Catalyst Optimizer, CBO
